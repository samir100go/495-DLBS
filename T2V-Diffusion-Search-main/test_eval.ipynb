# %%
# !pwd
# Out:
# /content

# %%
# !pip install decord

# %%
import decord

# %%
# !python /content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/evaluate.py \
    --videos_path /content/495-DLBS/DLBS-videos \
    --dimension subject_consistency overall_consistency aesthetic_quality imaging_quality motion_smoothness dynamic_degree temporal_flickering object_class multiple_objects spatial_relationship appearance_style temporal_style \
    --mode custom_input \
    --prompt_file /content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/prompts.json
# Out:
# args: Namespace(output_path='./evaluation_results/', full_json_dir='/content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/vbench/VBench_full_info.json', videos_path='/content/495-DLBS/DLBS-videos', dimension=['subject_consistency', 'overall_consistency', 'aesthetic_quality', 'imaging_quality', 'motion_smoothness', 'dynamic_degree', 'temporal_flickering', 'object_class', 'multiple_objects', 'spatial_relationship', 'appearance_style', 'temporal_style'], load_ckpt_from_local=None, read_frame=None, mode='custom_input', prompt='None', prompt_file='/content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/prompts.json', category=None, imaging_quality_preprocessing_mode='longer')
# start evaluation
# /usr/local/lib/python3.12/dist-packages/torch/distributed/c10d_logger.py:83: UserWarning: barrier(): using the device under current context. You can specify `device_id` in `init_process_group` to mute this warning.
#   return func(*args, **kwargs)
# ...
