# %%
# !pwd
# Out:
# /content

# %%
# !pip install decord

# %%
import decord

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-io7qb9ck
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-io7qb9ck
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install pyiqa==0.1.10 openai-clip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 25.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 82.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 40.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 36.0 MB/s eta 0:00:00
# ...
#   Created wheel for openai-clip: filename=openai_clip-1.0.1-py3-none-any.whl size=1368605 sha256=76dd57c6f52a0430e5fea0edca02430606d6f48dbad230af578b0c8db505b207
# ...

# %%
# !pip install -r /content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.8 MB/s eta 0:00:00
# ...
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement torch<2.0.0,>=1.12 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0)
# ERROR: No matching distribution found for torch<2.0.0,>=1.12

# %%
# !pip install "numpy<2.0.0"
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 136.7 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !python /content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/evaluate.py \
    --videos_path /content/495-DLBS/DLBS-videos \
    --dimension subject_consistency overall_consistency aesthetic_quality imaging_quality motion_smoothness dynamic_degree temporal_flickering temporal_style \
    --mode custom_input \
    --prompt_file /content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/prompts.json
# Out:
# args: Namespace(output_path='./evaluation_results/', full_json_dir='/content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/vbench/VBench_full_info.json', videos_path='/content/495-DLBS/DLBS-videos', dimension=['subject_consistency', 'overall_consistency', 'aesthetic_quality', 'imaging_quality', 'motion_smoothness', 'dynamic_degree', 'temporal_flickering', 'temporal_style'], load_ckpt_from_local=None, read_frame=None, mode='custom_input', prompt='None', prompt_file='/content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX/verifiers/VBench/prompts.json', category=None, imaging_quality_preprocessing_mode='longer')
# start evaluation
# /usr/local/lib/python3.12/dist-packages/torch/distributed/c10d_logger.py:83: UserWarning: barrier(): using the device under current context. You can specify `device_id` in `init_process_group` to mute this warning.
#   return func(*args, **kwargs)
# ...
