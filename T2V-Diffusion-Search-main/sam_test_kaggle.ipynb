# %% [markdown]
# ### Step 1: Set up the environment (Use a GPU!)
# Ensure you are running on a GPU. Go to **Runtime > Change runtime type** and select **T4 GPU** (or better).

# %% [markdown]
# ### Step 2: Clone the repository
# First, we need to clone the code from GitHub and navigate into the project directory.

# %%
# %cd /kaggle/working
# %cd /content
# !git clone https://github.com/samir100go/495-DLBS.git
# %cd 495-DLBS/T2V-Diffusion-Search-main
# Out:
# /content
# fatal: destination path '495-DLBS' already exists and is not an empty directory.
# /content/495-DLBS/T2V-Diffusion-Search-main

# %%
# %cd /kaggle/working
# !git clone https://github.com/shim0114/T2V-Diffusion-Search.git
# %cd T2V-Diffusion-Search
# Out:
# /kaggle/working
# Cloning into 'T2V-Diffusion-Search'...
# remote: Enumerating objects: 1207, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 1207 (delta 42), reused 50 (delta 20), pack-reused 1122 (from 1)
# Receiving objects: 100% (1207/1207), 45.03 MiB | 25.83 MiB/s, done.
# Resolving deltas: 100% (522/522), done.
# /kaggle/working/T2V-Diffusion-Search

# %%
# %cd /kaggle/working/495-DLBS
# %cd /content/495-DLBS/
# !git pull
# Out:
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 11 (delta 7), reused 11 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (11/11), 7.80 KiB | 1.95 MiB/s, done.
# From https://github.com/samir100go/495-DLBS
#    9c92c0d..77c408a  main       -> origin/main
# Updating 9c92c0d..77c408a
# Fast-forward
#  .../CogVideoX/verifiers/VBench/evaluate.py         |   3 +
#  T2V-Diffusion-Search-main/sam_test_kaggle.ipynb    |   4 +-
#  T2V-Diffusion-Search-main/test_eval.ipynb          | 360 +++++++++++++++++++--
#  .../verifiers/VBench/evaluate.py                   |   3 +
#  4 files changed, 348 insertions(+), 22 deletions(-)

# %%
rm -rf /kaggle/working/495-DLBS

# %% [markdown]
# ### Step 3: Install CogVideoX dependencies
# Install the specific requirements for CogVideoX.

# %%
# %cd CogVideoX
# !pip install -r requirements.txt
# %cd ..
# Out:
# /content/495-DLBS/T2V-Diffusion-Search-main/CogVideoX
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 90.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 124.0 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 109.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.6/416.6 kB 39.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -r /content/495-DLBS/T2V-Diffusion-Search-main/verifiers/VBench/requirements.txt
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement torch<2.0.0,>=1.12 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0)
# ERROR: No matching distribution found for torch<2.0.0,>=1.12

# %%
# !pip install decord
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 154.0 MB/s eta 0:00:0000:010:01
# ...

# %%
# !pwd
# !ls -la
# Out:
# /content/495-DLBS/T2V-Diffusion-Search-main
# total 312
# drwxr-xr-x 10 root root  4096 Apr 30 14:10  .
# drwxr-xr-x  4 root root  4096 Apr 30 14:10  ..
# drwxr-xr-x  4 root root  4096 Apr 30 14:10  CogVideoX
# drwxr-xr-x  5 root root  4096 Apr 30 14:10  configs
# drwxr-xr-x  2 root root  4096 Apr 30 14:10  diffusion
# -rw-r--r--  1 root root   843 Apr 30 14:10  Dockerfile
# -rw-r--r--  1 root root   540 Apr 30 14:10  download_weight.sh
# -rw-r--r--  1 root root 10244 Apr 30 14:10  .DS_Store
# -rw-r--r--  1 root root  3538 Apr 30 14:10  .gitignore
# -rw-r--r--  1 root root 64015 Apr 30 14:10 'gpu usage.png'
# drwxr-xr-x  2 root root  4096 Apr 30 14:10  images
# -rw-r--r--  1 root root 11357 Apr 30 14:10  LICENSE
# drwxr-xr-x  2 root root  4096 Apr 30 14:10  models
# -rw-r--r--  1 root root 16834 Apr 30 14:10  my_utils.py
# -rw-r--r--  1 root root  6027 Apr 30 14:10  README.md
# drwxr-xr-x  2 root root  4096 Apr 30 14:10  sample
# ...

# %% [markdown]
# ### Step 4: Download model weights
# This will download the required weights and move them into the `CogVideoX` folder.

# %%
# %cd T2V-Diffusion-Search-main/
# %cd /content/495-DLBS/T2V-Diffusion-Search-main/
# !bash download_weight.sh
# !cp -r pretrained CogVideoX
# Out:
# --2026-04-30 14:11:48--  https://huggingface.co/lalala125/AMT/resolve/main/amt-s.pth
# Resolving huggingface.co (huggingface.co)... 13.35.202.34, 13.35.202.40, 13.35.202.121, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.34|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ### Step 5: Run Inference (2B Model)
# We recommend starting with the 2B model in Colab to avoid Out-Of-Memory errors. Uncomment the DLBS lines if you want to use the search strategy.

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-pv7ttyyo
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-pv7ttyyo
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.4 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=8a06c9fe9dddc07d26da9ac130938ac9911c7cffa669eb09d2fc73171f7744a4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dvk8yv7z/wheels/35/3e/df/3d24cbfb3b6a06f17a2bfd7d1138900d4365d9028aa8f6e92f
# Successfully built clip
# ...

# %%
# Standard generation (No DLBS search)
# !python CogVideoX/sample_2b.py --config CogVideoX/configs/kb1/very_high.yaml

# OR - With Standard DLBS search
# !python CogVideoX/sample_2b.py --config CogVideoX/configs/dlbs/very_high.yaml

# OR - With DLBS-LA (Look-Ahead/backtracking search)
# !python CogVideoX/sample_2b.py --config CogVideoX/configs/dlbs_la/very_high.yaml
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# --2026-04-30 14:12:53--  https://raw.githubusercontent.com/openai/CLIP/main/clip/bpe_simple_vocab_16e6.txt.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1356917 (1.3M) [application/octet-stream]
# Saving to: ‘/root/.cache/vbench/ViCLIP/bpe_simple_vocab_16e6.txt.gz’
#
# bpe_simple_vocab_16 100%[===================>]   1.29M  --.-KB/s    in 0.006s
#
# ...

# %% [markdown]
# ### Step 6: Run Inference (5B Model)
# If you have access to a high-VRAM GPU (like A100/L4), you can use the 5B model.

# %%
# Standard generation (No DLBS search)
# !python CogVideoX/sample.py --config CogVideoX/configs/kb1/very_high.yaml

# OR - With Standard DLBS search
# !python CogVideoX/sample.py --config CogVideoX/configs/dlbs/very_high.yaml

# OR - With DLBS-LA (Look-Ahead/backtracking search)
# !python CogVideoX/sample.py --config CogVideoX/configs/dlbs_la/very_high.yaml
