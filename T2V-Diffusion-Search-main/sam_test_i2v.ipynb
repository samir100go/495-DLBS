# %%
# Cell 1: Change to the correct directory (use %cd, not !cd)
# %cd "/Users/samir/Library/CloudStorage/GoogleDrive-sakibul100@gmail.com/My Drive/1- University Academics/2-CSE495B/project/495-DLBS/T2V-Diffusion-Search-main/Wan2.1"

# %%
# Cell 2: Download the model weights using huggingface-cli
# !pip install "huggingface_hub[cli]" -q
# !huggingface-cli download Wan-AI/Wan2.1-I2V-14B-720P --local-dir ./Wan2.1-I2V-14B-720P

# %%
# Cell 3: Run the generation script
# !python generate.py \
  --task i2v-14B \
  --size "1280*720" \
  --ckpt_dir ./Wan2.1-I2V-14B-720P \
  --image /path/to/your/input_image.jpg \
  --prompt "A descriptive prompt of what should happen in the video..." \
  --sample_steps 40 \
  --sample_shift 5.0
